# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['prompts', 'answers'])

# %%
from langchain.chat_models import ChatOpenAI
from langchain.sql_database import SQLDatabase
from langchain_experimental.sql import SQLDatabaseChain
from dotenv import load_dotenv
load_dotenv()
api_key=['OPENAI_API_KEY']

# %%
db = SQLDatabase.from_uri("sqlite:///../data/processed/test_prices.db")
llm = ChatOpenAI(temperature=0,model_name='gpt-3.5-turbo')
cadena = SQLDatabaseChain(llm = llm, database = db, verbose=False)
formato = """
            Dada una pregunta del usuario:
            0. Convierte cualquier fecha al formato YYYY-MM-DD para mejor comprension del query
            1. crea una o varias consultas en las tablas de sqlite3 segun la pregunta (no le pongas limit a la consulta), si no se puede crear un query comunica que no tenemos data disponible de esos temas
            2. revisa los resultados, considera todas las columnas importantes al dar la respuesta
            3. devuelve el dato o los datos como un listado (incluye los valores de todas las columnas que consideres relevantes)
            4. añade un resumen con un analisis relevante de los datos mostrado y si hay noticias relacionadas en español, de no existir una noticia relevante, no la incluyas
            5. dale una estructura a la respuesta para que sea comoda de leer para el lector
            6. Si no sabes que responder, pregunta al usuario para obtener mas informacion, si no puedes obtener mas informacion, responde con el siguiente mensaje: "No tengo suficiente informacion para responder a tu pregunta"
            7. Siempre responde en español, y con palabras no tecnicas , un lenguaje cordial
            8. Siempre revisa la respuesta antes de enviarla, para asegurarte de que sea coherente y tenga sentido
            9. Siempre revisa la ortografia antes de enviar la respuesta
            10. Siempre que la respuesta contenga un dato numerico, añade la unidad de medida correspondiente y asegurate de que maximos tenga 2 decimales
            11. Siempre que la respuesta contenga la palabra null o none o NaN, cambia la respuesta a "No tenemos informacion disponible sobre ese tema"
            12. Si vas a presentar una tabla, asegurate de que los numeros maximo cuenten con 2 decimales.
            13. Siempre que vayas a dar una respuesta si en la respuesta encuentras algo asi "fue de X unidad de medida" di que no tenemos informacion disponible para responder a esa pregunta
            #{question}
            """
# Out:
# /home/juann/anaconda3/envs/BDI/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# /home/juann/anaconda3/envs/BDI/lib/python3.11/site-packages/langchain_experimental/sql/base.py:76: UserWarning: Directly instantiating an SQLDatabaseChain with an llm is deprecated. Please instantiate with llm_chain argument or using the from_llm class method.
#   warnings.warn(

# %%
def consulta(input_usuario):
    consulta = formato.format(question = input_usuario)
    
    try:
        resultado = cadena.run(consulta)
        return resultado
    
    except Exception as e:
        # If there's an exception, prompt ChatGPT for more information
        error_message = f"No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?"
        
        return error_message

# %%
with open('mutated_prompts.txt') as f:
    lines = f.readlines()
    for line in lines:
        answer = consulta(line)
        print(answer)
        with open('generated_answers_mutated.txt', 'a') as f:
            f.write(answer)
            f.write('\n')
# Out:
# /home/juann/anaconda3/envs/BDI/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# Provincia: Madrid
# Precio más alto: 202.02
#
# Resumen: Según los datos históricos, la provincia de Madrid tuvo el precio más alto para el cultivo de Maíz en 2022. No tenemos información disponible sobre otras provincias en ese año.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses de la siguiente manera:
#
# - El precio el 1 de enero de 2021 fue de 220.19 unidades de medida
# - El precio el 1 de diciembre de 2020 fue de 202.68 unidades de medida
# - El precio el 1 de noviembre de 2020 fue de 211.84 unidades de medida
# - El precio el 1 de octubre de 2020 fue de 204.74 unidades de medida
# - El precio el 1 de septiembre de 2020 fue de 195.79 unidades de medida
#
# Análisis: Se observa que el precio del Maíz de variedad Internacional ha experimentado fluctuaciones en los últimos meses, con un aumento significativo a principios de 2021. Estas variaciones pueden tener un impacto en la economía local y nacional, especialmente en sectores relacionados con la agricultura y la alimentación.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# En los últimos meses, el precio del Maíz de variedad Nacional en Madrid ha variado de la siguiente manera:
#
# 1. Fecha: 2021-01-01, Precio: 220.19
# 2. Fecha: 2020-12-31, Precio: 216.04
# 3. Fecha: 2020-12-30, Precio: 215.84
# 4. Fecha: 2020-12-29, Precio: 220.47
# 5. Fecha: 2020-12-28, Precio: 211.33
#
# Análisis: En los últimos días, el precio del Maíz de variedad Nacional en Madrid ha experimentado fluctuaciones, con un pico en el precio el 2021-01-01 y variaciones menores en días anteriores. No tenemos información disponible para responder a la pregunta sobre ejemplos históricos.
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses. En enero de 2019, el precio fue de 194.53 unidades de medida, mientras que en enero de 2021, el precio fue de 220.18 unidades de medida. La tendencia ha sido al alza en los últimos años, lo que podría estar relacionado con el calentamiento global.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses. En enero de 2019, el precio fue de 194.53 unidades de medida, y en enero de 2021, el precio fue de 220.18 unidades de medida. La tendencia ha sido al alza en los últimos años. No se puede establecer una relación directa entre el precio del maíz y el calentamiento global, ya que hay muchos factores que influyen en los precios de los cultivos.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# No tengo suficiente información para responder a tu pregunta.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses de la siguiente manera:
#
# - El precio el 1 de enero de 2021 fue de 220.19 unidades de medida
# - El precio el 1 de diciembre de 2020 fue de 202.68 unidades de medida
# - El precio el 1 de noviembre de 2020 fue de 211.84 unidades de medida
# - El precio el 1 de octubre de 2020 fue de 204.74 unidades de medida
# - El precio el 1 de septiembre de 2020 fue de 195.79 unidades de medida
#
# Análisis: Durante los últimos meses, el precio del Maíz de variedad Internacional en Madrid ha experimentado fluctuaciones significativas, con un aumento constante desde septiembre de 2020 hasta enero de 2021. Estas variaciones pueden tener un impacto en la economía local y nacional, especialmente en sectores relacionados con la agricultura y la alimentación.
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?

# %%
with open('mutated_prompts.txt') as f:
    lines = f.readlines()
    for line in lines:
        answer = consulta(line)
        print(answer)
        new_row = {'prompts': line, 'answers': answer}
        df = pd.concat([df, pd.DataFrame(new_row, index=[0])], ignore_index=True)
# Out:
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses de la siguiente manera:
#
# - El precio más alto registrado fue de 231.83 en abril de 2020.
# - El precio más bajo registrado fue de 185.19 en noviembre de 2020.
#
# En general, el precio ha experimentado fluctuaciones significativas a lo largo de los meses, lo que puede tener un impacto en la economía local y nacional.
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# En los últimos meses, el precio del Maíz de variedad Nacional en Madrid ha variado de la siguiente manera:
#
# 1. Fecha: 2021-01-01, Precio: 220.19
# 2. Fecha: 2020-12-31, Precio: 216.04
# 3. Fecha: 2020-12-30, Precio: 215.84
# 4. Fecha: 2020-12-29, Precio: 220.47
# 5. Fecha: 2020-12-28, Precio: 211.33
#
# Análisis: Según los datos recopilados, se observa que el precio del Maíz de variedad Nacional en Madrid ha experimentado fluctuaciones en los últimos meses, con valores que van desde 211.33 a 220.47. Es importante monitorear estas variaciones para comprender mejor las tendencias del mercado.
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# El precio del Maíz de variedad Nacional en Madrid ha variado en los últimos meses de la siguiente manera:
#
# - El precio más reciente es de 220.19 unidades de medida en la fecha 2021-01-01.
# - El precio más antiguo es de 194.53 unidades de medida en la fecha 2019-01-01.
#
# Análisis: Durante este período, el precio del Maíz de variedad Nacional en Madrid ha experimentado fluctuaciones significativas, con un aumento general a lo largo de los años. Esto puede tener un impacto en la economía local y en la vida cotidiana de los habitantes de Madrid que dependen de este cultivo.
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# No tengo suficiente información para responder a tu pregunta.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# No tengo suficiente información para responder a tu pregunta.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses. A lo largo de los últimos años, el precio ha oscilado entre aproximadamente 180 y 230 unidades monetarias. En los últimos meses, se observa una tendencia al alza en el precio, con valores superiores a 200 unidades monetarias. Esta variación en el precio del maíz puede tener un impacto significativo en la economía, especialmente en sectores como la agricultura, la alimentación y la industria.
# No tenemos información disponible sobre ese tema.
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tengo suficiente información para responder a tu pregunta.
# No tenemos información disponible sobre ese tema.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos información disponible sobre ese tema.
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses de la siguiente manera:
#
# - El precio el 1 de enero de 2021 fue de 220.19
# - El precio el 1 de diciembre de 2020 fue de 202.68
# - El precio el 1 de noviembre de 2020 fue de 211.84
# - El precio el 1 de octubre de 2020 fue de 204.74
# - El precio el 1 de septiembre de 2020 fue de 195.79
#
# Análisis: Durante los últimos meses, el precio del Maíz de variedad Internacional en Madrid ha experimentado fluctuaciones, con un aumento significativo a principios de 2021. Estas variaciones pueden tener un impacto en la economía local y en los precios de los productos alimenticios que dependen del maíz como materia prima.
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?
# No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?

# %%
ans=df[df["answers"] != "No tenemos datos disponibles sobre ese tema. ¿Puede proporcionar más detalles o hacer otra pregunta relacionada?"]

# %%
# let check if any answer contains the word null
ans[ans['answers'].str.contains("null")]
# Out:
# Empty DataFrame
# Columns: [prompts, answers]
# Index: []

# %%
#lets check if any answer contains the word None
ans[ans['answers'].str.contains("None")]
# Out:
# Empty DataFrame
# Columns: [prompts, answers]
# Index: []

# %%
#lets check if any answer contains the word nan 
ans[ans['answers'].str.contains("nan")]
# Out:
# Empty DataFrame
# Columns: [prompts, answers]
# Index: []

# %%
#lets check if any answer contains the word NaN
ans[ans['answers'].str.contains("NaN")]
# Out:
# Empty DataFrame
# Columns: [prompts, answers]
# Index: []

# %%
#lets check if any answer contains the word Lo siento or have No tenemos
len(ans[ans['answers'].str.contains("Lo siento") | ans['answers'].str.contains("No tenemos")])
# Out:
# 14

# %%
# lets iteratre over the answers
for index, row in ans.iterrows():
    print(row['prompts'])
    print(row['answers'])
# Out:
# ¿Cuál es la tendencia de precios para Cereales en Castilla y León desde 12/2023 hasta 7/2023? Can you provide an example from history?
#
# No tenemos información disponible sobre ese tema.
# Identificar las provincias con los precios más altos para Maíz en 2022. Can you provide an example from history?
#
# No tenemos información disponible sobre ese tema.
# Variación del precio de Maíz por cada Nacional desde 1/2023 hasta 8/2023. What are the future implications?
#
# No tengo suficiente información para responder a tu pregunta.
# Listar los precios promedios mensuales de Maíz en León durante 2023. Can technology solve this issue?
#
# No tenemos información disponible sobre ese tema.
# ¿Cómo ha variado el precio del Maíz de variedad Internacional en los últimos meses? What's the impact on the economy?
#
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses de la siguiente manera:
#
# - El precio más alto registrado fue de 231.83 en abril de 2020.
# - El precio más bajo registrado fue de 185.19 en noviembre de 2020.
#
# En general, el precio ha experimentado fluctuaciones significativas a lo largo de los meses, lo que puede tener un impacto en la economía local y nacional.
# ¿Cuál es la tendencia de precios para Cereales en Castilla y León desde 6/2023 hasta 8/2023? What's the scientific explanation?
#
# No tenemos información disponible sobre ese tema.
# ¿Cómo ha variado el precio del Maíz de variedad Nacional en los últimos meses? Can you provide an example from history?
#
# En los últimos meses, el precio del Maíz de variedad Nacional en Madrid ha variado de la siguiente manera:
#
# 1. Fecha: 2021-01-01, Precio: 220.19
# 2. Fecha: 2020-12-31, Precio: 216.04
# 3. Fecha: 2020-12-30, Precio: 215.84
# 4. Fecha: 2020-12-29, Precio: 220.47
# 5. Fecha: 2020-12-28, Precio: 211.33
#
# Análisis: Según los datos recopilados, se observa que el precio del Maíz de variedad Nacional en Madrid ha experimentado fluctuaciones en los últimos meses, con valores que van desde 211.33 a 220.47. Es importante monitorear estas variaciones para comprender mejor las tendencias del mercado.
# Identificar las provincias con los precios más altos para Maíz en 2023. How does this compare to traditional methods?
#
# No tenemos información disponible sobre ese tema.
# Identificar las provincias con los precios más altos para Maíz en 2023. What are the future implications?
#
# No tenemos información disponible sobre ese tema.
# Comparar el precio del Maíz nacional versus internacional en León para el año 2023. Can you provide an example from history?
#
# No tengo suficiente información para responder a tu pregunta.
# ¿Cómo ha variado el precio del Maíz de variedad Nacional en los últimos meses? How does this affect everyday life?
#
# El precio del Maíz de variedad Nacional en Madrid ha variado en los últimos meses de la siguiente manera:
#
# - El precio más reciente es de 220.19 unidades de medida en la fecha 2021-01-01.
# - El precio más antiguo es de 194.53 unidades de medida en la fecha 2019-01-01.
#
# Análisis: Durante este período, el precio del Maíz de variedad Nacional en Madrid ha experimentado fluctuaciones significativas, con un aumento general a lo largo de los años. Esto puede tener un impacto en la economía local y en la vida cotidiana de los habitantes de Madrid que dependen de este cultivo.
# ¿Cómo ha afectado la temporada a los precios de Cereales en León? What's the impact on the economy?
#
# No tenemos información disponible sobre ese tema.
# Identificar las provincias con los precios más altos para Maíz en 2022. How does this affect everyday life?
#
# No tenemos información disponible sobre ese tema.
# ¿Cuál ha sido el precio promedio del Maíz en León entre 1/2022 y 6/2022? How does this compare to traditional methods?
#
# No tenemos información disponible sobre ese tema
# Identificar las provincias con los precios más altos para Maíz en 2022. What are the future implications?
#
# No tengo suficiente información para responder a tu pregunta.
# Comparar el precio del Maíz nacional versus internacional en León para el año 2022. What are the future implications?
#
# No tengo suficiente información para responder a tu pregunta.
# Comparar el precio del Maíz nacional versus internacional en León para el año 2022. What's the impact on the economy?
#
# No tenemos información disponible sobre ese tema.
# Identificar las provincias con los precios más altos para Maíz en 2022. What's the scientific explanation?
#
# No tengo suficiente información para responder a tu pregunta.
# ¿Cómo ha variado el precio del Maíz de variedad Internacional en los últimos meses? What's the impact on the economy?
#
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses. A lo largo de los últimos años, el precio ha oscilado entre aproximadamente 180 y 230 unidades monetarias. En los últimos meses, se observa una tendencia al alza en el precio, con valores superiores a 200 unidades monetarias. Esta variación en el precio del maíz puede tener un impacto significativo en la economía, especialmente en sectores como la agricultura, la alimentación y la industria.
# Identificar las provincias con los precios más altos para Maíz en 2023. Can you provide an example from history?
#
# No tenemos información disponible sobre ese tema.
# ¿Cuál es la tendencia de precios para Cereales en Castilla y León desde 9/2022 hasta 10/2022? Can technology solve this issue?
#
# No tenemos información disponible sobre ese tema.
# Comparar el precio del Maíz nacional versus internacional en León para el año 2022. How does this affect everyday life?
#
# No tengo suficiente información para responder a tu pregunta.
# Listar los precios promedios mensuales de Maíz en León durante 2022. How does this compare to traditional methods?
#
# No tengo suficiente información para responder a tu pregunta.
# Identificar las provincias con los precios más altos para Maíz en 2022. How does this affect everyday life?
#
# No tenemos información disponible sobre ese tema.
# ¿Cuál ha sido el precio promedio del Maíz en León entre 8/2022 y 4/2022? Can you provide an example from history?
#
# No tenemos información disponible sobre ese tema.
# ¿Cómo ha variado el precio del Maíz de variedad Internacional en los últimos meses? What's the impact on the economy?
#
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses de la siguiente manera:
#
# - El precio el 1 de enero de 2021 fue de 220.19
# - El precio el 1 de diciembre de 2020 fue de 202.68
# - El precio el 1 de noviembre de 2020 fue de 211.84
# - El precio el 1 de octubre de 2020 fue de 204.74
# - El precio el 1 de septiembre de 2020 fue de 195.79
#
# Análisis: Durante los últimos meses, el precio del Maíz de variedad Internacional en Madrid ha experimentado fluctuaciones, con un aumento significativo a principios de 2021. Estas variaciones pueden tener un impacto en la economía local y en los precios de los productos alimenticios que dependen del maíz como materia prima.

# %%
clean = ans[~ans['answers'].str.contains("Lo siento") & (~ans['answers'].str.contains("No tenemos"))  & (~ans['answers'].str.contains("no tenemos"))]

# %%
len(clean)
# Out:
# 12

# %%
for index, row in clean.iterrows():
    print(row['prompts'])
    print(row['answers'])
# Out:
# Variación del precio de Maíz por cada Nacional desde 1/2023 hasta 8/2023. What are the future implications?
#
# No tengo suficiente información para responder a tu pregunta.
# ¿Cómo ha variado el precio del Maíz de variedad Internacional en los últimos meses? What's the impact on the economy?
#
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses de la siguiente manera:
#
# - El precio más alto registrado fue de 231.83 en abril de 2020.
# - El precio más bajo registrado fue de 185.19 en noviembre de 2020.
#
# En general, el precio ha experimentado fluctuaciones significativas a lo largo de los meses, lo que puede tener un impacto en la economía local y nacional.
# ¿Cómo ha variado el precio del Maíz de variedad Nacional en los últimos meses? Can you provide an example from history?
#
# En los últimos meses, el precio del Maíz de variedad Nacional en Madrid ha variado de la siguiente manera:
#
# 1. Fecha: 2021-01-01, Precio: 220.19
# 2. Fecha: 2020-12-31, Precio: 216.04
# 3. Fecha: 2020-12-30, Precio: 215.84
# 4. Fecha: 2020-12-29, Precio: 220.47
# 5. Fecha: 2020-12-28, Precio: 211.33
#
# Análisis: Según los datos recopilados, se observa que el precio del Maíz de variedad Nacional en Madrid ha experimentado fluctuaciones en los últimos meses, con valores que van desde 211.33 a 220.47. Es importante monitorear estas variaciones para comprender mejor las tendencias del mercado.
# Comparar el precio del Maíz nacional versus internacional en León para el año 2023. Can you provide an example from history?
#
# No tengo suficiente información para responder a tu pregunta.
# ¿Cómo ha variado el precio del Maíz de variedad Nacional en los últimos meses? How does this affect everyday life?
#
# El precio del Maíz de variedad Nacional en Madrid ha variado en los últimos meses de la siguiente manera:
#
# - El precio más reciente es de 220.19 unidades de medida en la fecha 2021-01-01.
# - El precio más antiguo es de 194.53 unidades de medida en la fecha 2019-01-01.
#
# Análisis: Durante este período, el precio del Maíz de variedad Nacional en Madrid ha experimentado fluctuaciones significativas, con un aumento general a lo largo de los años. Esto puede tener un impacto en la economía local y en la vida cotidiana de los habitantes de Madrid que dependen de este cultivo.
# Identificar las provincias con los precios más altos para Maíz en 2022. What are the future implications?
#
# No tengo suficiente información para responder a tu pregunta.
# Comparar el precio del Maíz nacional versus internacional en León para el año 2022. What are the future implications?
#
# No tengo suficiente información para responder a tu pregunta.
# Identificar las provincias con los precios más altos para Maíz en 2022. What's the scientific explanation?
#
# No tengo suficiente información para responder a tu pregunta.
# ¿Cómo ha variado el precio del Maíz de variedad Internacional en los últimos meses? What's the impact on the economy?
#
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses. A lo largo de los últimos años, el precio ha oscilado entre aproximadamente 180 y 230 unidades monetarias. En los últimos meses, se observa una tendencia al alza en el precio, con valores superiores a 200 unidades monetarias. Esta variación en el precio del maíz puede tener un impacto significativo en la economía, especialmente en sectores como la agricultura, la alimentación y la industria.
# Comparar el precio del Maíz nacional versus internacional en León para el año 2022. How does this affect everyday life?
#
# No tengo suficiente información para responder a tu pregunta.
# Listar los precios promedios mensuales de Maíz en León durante 2022. How does this compare to traditional methods?
#
# No tengo suficiente información para responder a tu pregunta.
# ¿Cómo ha variado el precio del Maíz de variedad Internacional en los últimos meses? What's the impact on the economy?
#
# El precio del Maíz de variedad Internacional en Madrid ha variado en los últimos meses de la siguiente manera:
#
# - El precio el 1 de enero de 2021 fue de 220.19
# - El precio el 1 de diciembre de 2020 fue de 202.68
# - El precio el 1 de noviembre de 2020 fue de 211.84
# - El precio el 1 de octubre de 2020 fue de 204.74
# - El precio el 1 de septiembre de 2020 fue de 195.79
#
# Análisis: Durante los últimos meses, el precio del Maíz de variedad Internacional en Madrid ha experimentado fluctuaciones, con un aumento significativo a principios de 2021. Estas variaciones pueden tener un impacto en la economía local y en los precios de los productos alimenticios que dependen del maíz como materia prima.

# %%
#lets save the clean data
clean.to_csv('clean_answers_mutated.csv', index=False)
